# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df=pd.read_excel("Superstore_USA.xlsx")

# %% [markdown]
# the sample used here is not ideal and lacks some major and important columns

# %% [markdown]
# # CASE 1:

# %% [markdown]
# for the people with no prioir data  ,new profiles(customer)

# %% [markdown]
# recommends the most bought item ,since the data lacks rating or any other column that indicate the product reviews i am ranking them on the basis of "most bought" item . For this case using reviews and rating will create more benefitial results

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df['Product Name'].value_counts().head(20).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df['Product Name'].value_counts().head(10).keys()
# Out:
# Index(['Global High-Back Leather Tilter, Burgundy',
#        'Bevis 36 x 72 Conference Tables',
#        'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#        'Master Giant Foot® Doorstop, Safety Yellow',
#        'Wilson Jones Hanging View Binder, White, 1"',
#        'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms',
#        '80 Minute CD-R Spindle, 100/Pack - Staples',
#        'Fiskars® Softgrip Scissors', 'StarTAC 7760',
#        'Peel & Seel® Recycled Catalog Envelopes, Brown'],
#       dtype='object')
