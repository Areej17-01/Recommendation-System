# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df=pd.read_excel("Superstore_USA.xlsx")

# %% [markdown]
# ## OUTLIERS

# %% [markdown]
# ### box plots

# %% [markdown]
# Each components tells different info
#
# outliers detection

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
sns.boxplot(x=df.Sales,y=df.Region)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Region'>

# %%
def box(x, fig):
    plt.subplot(5,2,fig)
    plt.boxplot(df[x])
    plt.title(x)
   # plt.ylabel("Price")
    #plt.xlabel(x)
    
plt.figure(figsize=(10,20))

box('Sales',1)
box('Profit',2)
box('Unit Price',3)
box('Discount',4)

plt.tight_layout()

# %% [markdown]
# ## correlation b/w sales and profit

# %%
fig = plt.figure(figsize=(10,10))
plt.ylim(-4000,8000)
plt.xlim(-1000,13000)
sns.scatterplot(df.Sales,df.Profit,palette=("magma"))
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
cor = np.abs(df.corr()["Profit"])
cor[cor > 0.5]
# Out:
# Profit    1.0
# Name: Profit, dtype: float64

# %%
cor["Sales"],cor["Profit"]
# Out:
# (0.3715830697718407, 1.0)

# %% [markdown]
# that straight line determines the bit of +ve linear points that shows they are a bit correlated to each other

# %% [markdown]
# ### Violin plot

# %%
def violine(x, fig):
    plt.subplot(5,2,fig)
    sns.violinplot(df[x],palette=("magma"))
    plt.title(x)
   # plt.ylabel("Price")
    #plt.xlabel(x)
    
plt.figure(figsize=(10,20))

violine('Sales',1)
violine('Profit',2)
violine('Unit Price',3)
violine('Discount',4)

plt.tight_layout()
